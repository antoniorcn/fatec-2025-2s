# %%
# !python -m pip uninstall tensorflow

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from string import punctuation

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import CategoryEncoding, Input, Dense, LSTM, StringLookup, Embedding

# %%
from sklearn.model_selection import train_test_split

# %%
nltk.download('punkt') # Necessário para word_tokenize
nltk.download('stopwords')
palavras_remover = set(stopwords.words())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anton\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anton\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
df = pd.read_csv("../../../dados/nlp/dialogs.txt", sep="\t" , encoding="utf-8", 
                 header=None, names=["Perguntas", "Respostas"])

# %%
df["Perguntas"].shape
# Out:
# (3725,)

# %%
entradas = df["Perguntas"] + df["Respostas"]
entradas.shape
# Out:
# (3725,)

# %%
def limpar_texto( texto ):
    translator = str.maketrans('—’', '  ', punctuation)
    texto_limpo = texto.lower().translate( translator )
    tokens = word_tokenize(texto_limpo)
    tokens_limpos = []
    for token in tokens:
        # if token not in palavras_remover:
        tokens_limpos.append(token)
    return " ".join(tokens_limpos)

# %%
entradas_limpo = entradas.apply( limpar_texto )

# %%
MAX_PALAVRAS = 5000

# %%
tokenizer = Tokenizer(num_words = MAX_PALAVRAS, oov_token="<UNKNOW>") # OOV = Out Of Vocabulary

# %%
tokenizer.fit_on_texts( entradas_limpo )
len(tokenizer.word_index)
# Out:
# 5629

# %%
sequencias = tokenizer.texts_to_sequences( entradas_limpo )

# %%
sequencias[0:5]
# Out:
# [[1463, 48, 15, 2, 1464, 619, 48, 26, 808],
#  [36, 619, 48, 26, 2347, 159, 41, 363, 19, 527],
#  [36, 159, 41, 363, 19, 2348, 193, 29, 48, 12, 2, 86],
#  [43, 193, 29, 48, 12, 2, 2349, 86, 96, 16, 26, 2],
#  [119, 86, 96, 16, 26, 2350, 86, 41, 36, 14, 99, 68, 137]]

# %% [raw]
# sequencias = [
#     [ 2, 65, 1, 43, 29, 12, 10, 8, 5 ],
#     [ 4, 78, 98 ],
#     ...
#
# ]

# %% [raw]
# entradas = [
#  [ 2, 65, 1, 43, 29],       # "hi how are you doing"
#  [4, 78, 98, 10, 8, 5]      # "i am fine how about yourself"
# ]
#
# # X                       Y
# 2, 65                     1
# 2, 65, 1                  43
# 2, 65, 1, 43              29
# 4, 78                     98
# 4, 78, 98                 10
# 4, 78, 98, 10             8
# 4, 78, 98, 10, 8          5
#
# # X                       Y
# # hi how                  are
# # hi how are              you
# # hi how are you          doing
# # i am                    fine
# # i am fine               how
# # i am fine how           about
# # i am fine how about     yourself

# %%
entradas_features = []
saidas_labels = []

for sequencia in sequencias:
# [ 2, 65, 1, 43, 29]     ==> len(sequencia)  => 5
    for i in range(2, len(sequencia)):
        features = sequencia[0: i]
        label = sequencia[i]
        entradas_features.append( features )
        saidas_labels.append( label )
len(entradas_features),    len(saidas_labels)
# Out:
# (36786, 36786)

# %%
sequencias_padded = np.array(pad_sequences( entradas_features, padding="pre" ))
sequencias_padded.shape
# Out:
# (36786, 30)

# %%
output_encoder = CategoryEncoding( num_tokens=MAX_PALAVRAS, output_mode="one_hot" )
saida_encoded = output_encoder( saidas_labels ).numpy()
saida_encoded.shape
# Out:
# (36786, 5000)

# %%
modelo = Sequential()
modelo.add(  Embedding( input_dim=(MAX_PALAVRAS + 1), output_dim=50, mask_zero=False )  )
modelo.add( LSTM(128) )
modelo.add( Dense( MAX_PALAVRAS, activation="softmax") )
modelo.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_9 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo.compile( optimizer="adam", loss="categorical_crossentropy", metrics=["Accuracy"])

# %%
X_train, X_test, Y_train, Y_test = train_test_split( sequencias_padded, saida_encoded, test_size=0.05, random_state=100 )
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((34946, 30), (1840, 30), (34946, 5000), (1840, 5000))

# %%
resultado = modelo.fit( X_train, Y_train, epochs=35, batch_size=32 )
# Out:
# Epoch 1/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 32s 27ms/step - Accuracy: 0.0427 - loss: 6.6585
# Epoch 2/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.0632 - loss: 6.1629
# Epoch 3/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.0873 - loss: 5.8363
# Epoch 4/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.1141 - loss: 5.4689
# Epoch 5/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.1402 - loss: 5.1095
# Epoch 6/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.1596 - loss: 4.7834
# Epoch 7/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.1804 - loss: 4.4861
# Epoch 8/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.2047 - loss: 4.1970
# Epoch 9/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.2279 - loss: 3.9195
# Epoch 10/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 26ms/step - Accuracy: 0.2572 - loss: 3.6537
# Epoch 11/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.2912 - loss: 3.3969
# Epoch 12/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.3271 - loss: 3.1581
# Epoch 13/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.3632 - loss: 2.9382
# Epoch 14/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.4019 - loss: 2.7348
# Epoch 15/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.4370 - loss: 2.5520
# Epoch 16/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.4709 - loss: 2.3898
# Epoch 17/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.5003 - loss: 2.2376
# Epoch 18/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.5294 - loss: 2.1035
# Epoch 19/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.5559 - loss: 1.9781
# Epoch 20/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.5813 - loss: 1.8614
# Epoch 21/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.6046 - loss: 1.7528
# Epoch 22/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.6252 - loss: 1.6549
# Epoch 23/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.6489 - loss: 1.5603
# Epoch 24/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.6685 - loss: 1.4740
# Epoch 25/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.6858 - loss: 1.3909
# Epoch 26/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.7030 - loss: 1.3173
# Epoch 27/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.7207 - loss: 1.2446
# Epoch 28/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.7351 - loss: 1.1777
# Epoch 29/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.7486 - loss: 1.1150
# Epoch 30/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.7595 - loss: 1.0576
# Epoch 31/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.7763 - loss: 1.0018
# Epoch 32/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.7870 - loss: 0.9508
# Epoch 33/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.7961 - loss: 0.9036
# Epoch 34/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - Accuracy: 0.8071 - loss: 0.8586
# Epoch 35/35
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - Accuracy: 0.8164 - loss: 0.8165

# %%
modelo.evaluate( X_test, Y_test )
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - Accuracy: 0.2293 - loss: 7.1838
# [7.183772087097168, 0.229347825050354]

# %%
acuracia = resultado.history["Accuracy"]
perda = resultado.history["loss"] / np.max(resultado.history["loss"]) 
plt.plot(acuracia, color="green")
plt.plot(perda, color="red")

# %%
texto = "hi i am Antonio what is your favorite kind of music is she gave"

# %%
texto_limpo = limpar_texto( texto )
texto_limpo
# Out:
# 'hi i am antonio what is your favorite kind of music is she gave'

# %%
sequencias = tokenizer.texts_to_sequences( [texto_limpo] )
texto_seq_padded = pad_sequences( sequencias, maxlen=sequencias_padded.shape[1], padding="pre")
predicted = modelo.predict( texto_seq_padded )
pos_palavra = np.argmax( predicted )
for item in tokenizer.word_index.items():
    if item[1] == pos_palavra:
        print(item[0])
        break
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# me
